# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
import seaborn as sn

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Temperature Forecast Project.csv")

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# ...

# %%
df.shape
# Out:
# (7752, 25)

# %% [markdown]
# There are 7752 rows and 25 columns

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# There are null values in the dataset

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# Here one column is in object.  Other columns are in numerical values

# %%
df=df.dropna()

# %% [markdown]
# Dropped the null values

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %% [markdown]
# Dropped all null values

# %%
plt.figure(figsize=(16,5))
sn.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the heatmap we can see that there are no values present in it.

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7588.000000   7588.000000   7588.000000  7588.000000  7588.000000
# mean     13.014101     29.748366     23.195809    56.724969    88.360823
# std       7.217858      2.967401      2.400880    14.626559     7.199456
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.600000    45.960243    84.203724
# 50%      13.000000     29.900000     23.400000    55.023199    89.784122
# 75%      19.000000     32.000000     24.800000    67.115099    93.742725
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7588.000000       7588.000000  7588.000000  7588.000000
# mean          29.620128         23.511786     7.094097    62.492606
# std            2.943496          2.342579     2.177034    33.686158
# ...

# %% [markdown]
# These are the statistical values of the dataset

# %%
df.shape
# Out:
# (7588, 25)

# %% [markdown]
# # EDA

# %% [markdown]
# Univariate analysis

# %%
sn.countplot(df['LDAPS_RHmin']);

# %%
sn.countplot(df['LDAPS_RHmax']);

# %% [markdown]
# These are the countplot of LDAPS_RHmax and RHmin against the count

# %%
sn.countplot(df['Next_Tmax']);

# %%
sn.countplot(df['Next_Tmin']);

# %% [markdown]
# These are the countplot of Next_Tmin and Next_Tmax against count

# %%
sn.displot(df['LDAPS_Tmax_lapse']);

# %% [markdown]
# These are the displot of LDAPS_Tmax  against count.  Its normaly distributed

# %%
sn.displot(df['LDAPS_Tmin_lapse']);

# %% [markdown]
# These are the displot of  LDAPS_Tmin against count.  Its left skewed

# %%
sn.displot(df['Solar radiation']);

# %% [markdown]
# These are the displot of Solar radiation against count.  Its left skewed

# %%
sn.displot(df['Next_Tmax']);

# %% [markdown]
# These are the displot of Next_Tmax against count.  Its normaly distributed

# %%
sn.displot(df['Next_Tmin']);

# %% [markdown]
# This also normaly distributed

# %% [markdown]
# plt.figure(figsize=(25,20))
# for i in enumerate (df.columns):
#     plt.subplot(8,4,i[0]+1)
#     sn.displot(df[i[1]],color='g')

# %% [markdown]
# # Bivariate analysis

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Present_Tmin and Next_Tmin")
sn.scatterplot(df['Present_Tmin'],df['Next_Tmin'],hue=df["Next_Tmin"])
# Out:
# <AxesSubplot:title={'center':'comparison between Present_Tmin and Next_Tmin'}, xlabel='Present_Tmin', ylabel='Next_Tmin'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Present_Tax and Next_Tmax")
sn.scatterplot(df['Present_Tmax'],df['Next_Tmax'],hue=df["Next_Tmax"])
# Out:
# <AxesSubplot:title={'center':'comparison between Present_Tax and Next_Tmax'}, xlabel='Present_Tmax', ylabel='Next_Tmax'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between station and Next_Tmin")
sn.scatterplot(df['station'],df['Next_Tmin'],hue=df["Next_Tmin"])
# Out:
# <AxesSubplot:title={'center':'comparison between station and Next_Tmin'}, xlabel='station', ylabel='Next_Tmin'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between station and generation_gwh_2013")
sn.scatterplot(df['station'],df['Next_Tmax'],hue=df["Next_Tmax"])
# Out:
# <AxesSubplot:title={'center':'comparison between station and generation_gwh_2013'}, xlabel='station', ylabel='Next_Tmax'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Solar radiation and Next_Tmin")
sn.scatterplot(df['Solar radiation'],df['Next_Tmin'],hue=df["Next_Tmin"])
# Out:
# <AxesSubplot:title={'center':'comparison between Solar radiation and Next_Tmin'}, xlabel='Solar radiation', ylabel='Next_Tmin'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between Solar radiation and Next_Tmax")
sn.scatterplot(df['Solar radiation'],df['Next_Tmax'],hue=df["Next_Tmax"])
# Out:
# <AxesSubplot:title={'center':'comparison between Solar radiation and Next_Tmax'}, xlabel='Solar radiation', ylabel='Next_Tmax'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between LDAPS_Tmax_lapse and Next_Tmax")
sn.scatterplot(df['LDAPS_Tmax_lapse'],df['Next_Tmax'],hue=df["Next_Tmax"])
# Out:
# <AxesSubplot:title={'center':'comparison between LDAPS_Tmax_lapse and Next_Tmax'}, xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmax'>

# %%
plt.figure(figsize=[10,6])
plt.title("comparison between LDAPS_Tmin_lapse and Next_Tmin")
sn.scatterplot(df['LDAPS_Tmin_lapse'],df['Next_Tmin'],hue=df["Next_Tmin"])
# Out:
# <AxesSubplot:title={'center':'comparison between LDAPS_Tmin_lapse and Next_Tmin'}, xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmin'>

# %% [markdown]
# These are the distribution of min and max columns against the target columns Next_min and Next_max.  We can see that some outliers are present in some distributions

# %%
cor=df.corr()
cor
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.113301      0.133282    -0.067846
# Present_Tmax      0.113301      1.000000      0.615208    -0.209059
# Present_Tmin      0.133282      0.615208      1.000000     0.122200
# LDAPS_RHmin      -0.067846     -0.209059      0.122200     1.000000
# LDAPS_RHmax      -0.169351     -0.306943     -0.018576     0.578358
# LDAPS_Tmax_lapse  0.069856      0.573777      0.467904    -0.569580
# LDAPS_Tmin_lapse  0.105277      0.628705      0.772061     0.085237
# LDAPS_WS          0.005822     -0.125952     -0.038779     0.289422
# LDAPS_LH         -0.132129      0.134246     -0.012817    -0.072195
# LDAPS_CC1         0.006539     -0.316333      0.084348     0.612831
# LDAPS_CC2         0.003526     -0.216976      0.090038     0.744774
# LDAPS_CC3        -0.000161     -0.146391     -0.004719     0.688069
# LDAPS_CC4         0.005005     -0.143069     -0.046694     0.513937
# ...

# %% [markdown]
# These are the correlation  values between the columns

# %%
plt.figure(figsize=[30,20])
sn.heatmap(cor,annot=True,linewidths=6,linecolor='r')
# Out:
# <AxesSubplot:>

# %% [markdown]
# From this heatmap we can see that there are 4 columns which is highly negatively correlated with target column Next_Tmax

# %% [markdown]
# plt.figure(figsize=(18,10))
# for o in enumerate(df):
#     plt.subplot(9,4,o[0]+1)
#     sns.boxplot(df[o[1]])

# %%
df.plot(kind="box",subplots=True,layout=(5,5))
# Out:
# station                AxesSubplot(0.125,0.749828;0.133621x0.130172)
# Present_Tmax        AxesSubplot(0.285345,0.749828;0.133621x0.130172)
# Present_Tmin         AxesSubplot(0.44569,0.749828;0.133621x0.130172)
# LDAPS_RHmin         AxesSubplot(0.606034,0.749828;0.133621x0.130172)
# LDAPS_RHmax         AxesSubplot(0.766379,0.749828;0.133621x0.130172)
# LDAPS_Tmax_lapse       AxesSubplot(0.125,0.593621;0.133621x0.130172)
# LDAPS_Tmin_lapse    AxesSubplot(0.285345,0.593621;0.133621x0.130172)
# LDAPS_WS             AxesSubplot(0.44569,0.593621;0.133621x0.130172)
# LDAPS_LH            AxesSubplot(0.606034,0.593621;0.133621x0.130172)
# LDAPS_CC1           AxesSubplot(0.766379,0.593621;0.133621x0.130172)
# LDAPS_CC2              AxesSubplot(0.125,0.437414;0.133621x0.130172)
# LDAPS_CC3           AxesSubplot(0.285345,0.437414;0.133621x0.130172)
# LDAPS_CC4            AxesSubplot(0.44569,0.437414;0.133621x0.130172)
# LDAPS_PPT1          AxesSubplot(0.606034,0.437414;0.133621x0.130172)
# ...

# %% [markdown]
# From this plot we can see that there are outliers present in most of the columns

# %% [markdown]
# # Converting string data into numerical data by using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Date']=le.fit_transform(df['Date'])

# %%
df.dtypes
# Out:
# station             float64
# Date                  int32
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %% [markdown]
# All the columns changed into numerical values

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
df1=df[(z<3).all(axis=1)]

# %% [markdown]
# # skewness

# %%
df1.skew()
# Out:
# station            -0.001594
# Date                0.007902
# Present_Tmax       -0.269936
# Present_Tmin       -0.221250
# LDAPS_RHmin         0.309567
# LDAPS_RHmax        -0.686083
# LDAPS_Tmax_lapse   -0.110563
# LDAPS_Tmin_lapse   -0.379269
# LDAPS_WS            1.085685
# LDAPS_LH            0.567050
# LDAPS_CC1           0.594835
# LDAPS_CC2           0.505774
# LDAPS_CC3           0.701288
# LDAPS_CC4           0.708754
# LDAPS_PPT1          3.724580
# LDAPS_PPT2          4.854967
# LDAPS_PPT3          5.516862
# LDAPS_PPT4          5.924324
# lat                 0.106983
# lon                -0.277547
# DEM                 1.764698
# Slope               1.590130
# Solar radiation    -0.520157
# Next_Tmax          -0.267526
# Next_Tmin          -0.234328
# dtype: float64

# %% [markdown]
# skew +/- 5 will be treated

# %%
from sklearn.preprocessing import power_transform

# %%
df1[['LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','DEM','Slope']]=power_transform(df1[['LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','DEM','Slope']])

# %%
df=df1

# %%
df1.skew()
# Out:
# station            -0.001594
# Date                0.007902
# Present_Tmax       -0.269936
# Present_Tmin       -0.221250
# LDAPS_RHmin         0.309567
# LDAPS_RHmax        -0.686083
# LDAPS_Tmax_lapse   -0.110563
# LDAPS_Tmin_lapse   -0.379269
# LDAPS_WS            1.085685
# LDAPS_LH            0.567050
# LDAPS_CC1           0.594835
# LDAPS_CC2           0.505774
# LDAPS_CC3           0.701288
# LDAPS_CC4           0.708754
# LDAPS_PPT1          1.617538
# LDAPS_PPT2          1.820237
# LDAPS_PPT3          1.995359
# LDAPS_PPT4          2.267954
# lat                 0.106983
# lon                -0.277547
# DEM                 0.038830
# Slope               0.233799
# Solar radiation    -0.520157
# Next_Tmax          -0.267526
# Next_Tmin          -0.234328
# dtype: float64

# %%
df.shape
# Out:
# (6739, 25)

# %% [markdown]
# There are some rows removed because of skewness

# %% [markdown]
# # Dividing Data into x and y

# %% [markdown]
# treating Next_Tmax as a target and treating like regression in first case and in second case treating Next_Tmin as a target

# %%
x=df.drop(["Next_Tmax","Next_Tmin"],axis=1)
y1=df["Next_Tmax"]
y2=df["Next_Tmin"]

# %%
x.shape
# Out:
# (6739, 23)

# %%
y1.shape
# Out:
# (6739,)

# %%
y2.shape
# Out:
# (6739,)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import MinMaxScaler

sc=MinMaxScaler()
x=sc.fit_transform(x)

# %% [markdown]
# done the scaling

# %% [markdown]
# # Splitting the Data for Training and Testing

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
lr=LinearRegression()

# %%
x_train,x_test,y1_train,y1_test=train_test_split(x,y1,test_size=.2,random_state=12)

# %%
lr.fit(x_train,y1_train)
# Out:
# LinearRegression()

# %% [markdown]
# linear regression fitting into x-train and y-train

# %%
lr.coef_
# Out:
# array([ 0.50594785,  0.10369728,  2.87673651,  0.80835322,  2.07511887,
#        -0.27878165, 10.52655602,  0.46256568, -1.45689124,  1.41448661,
#        -0.5903134 , -0.26003399, -0.81930276, -1.61831192, -0.42533681,
#        -0.40833858, -0.06944477,  0.32279408, -0.14360305, -0.46812154,
#        -0.02172338,  0.0842373 ,  0.21970192])

# %% [markdown]
# Got the linear regression coefficient

# %%
lr.intercept_
# Out:
# 23.069861711976905

# %% [markdown]
# Got the linear regression constant

# %%
pred_test=lr.predict(x_test)

# %%
print("predicted value is",pred_test)
print("actual value is",y1_test)
# Out:
# predicted value is [29.2779336  31.40250327 30.96005735 ... 31.8760476  31.09265215
#  35.60353477]
# actual value is 5006    28.6
# 6479    31.5
# 4434    31.7
# 2347    35.6
# 6723    33.2
#         ...
# 7038    33.7
# 7318    26.3
# 1813    33.0
# 1440    29.3
# 5541    35.7
# Name: Next_Tmax, Length: 1348, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("mean absoute value",mean_absolute_error(y1_test,pred_test))
print("mean squared error",mean_squared_error(y1_test,pred_test))
print ("Root mean squared error",np.sqrt(mean_squared_error(y1_test,pred_test)))
# Out:
# mean absoute value 1.0866254515672988
# mean squared error 2.09996568128225
# Root mean squared error 1.449125833487986

# %%
print(r2_score(y1_test,pred_test))
# Out:
# 0.7560269841061599

# %% [markdown]
# got the prediction as 76%

# %% [markdown]
# # SVR(linear)

# %%
from sklearn.svm import SVR

svr = SVR(kernel='linear')
svr.fit(x_train,y1_train)
print(svr.score(x_train,y1_train))
svr_predict=svr.predict(x_test)
# Out:
# 0.7600385610201457

# %%
print('MSE:',mean_squared_error(svr_predict,y1_test))
print('MAE:',mean_absolute_error(svr_predict,y1_test))
print('r2_score:',r2_score(svr_predict,y1_test))
# Out:
# MSE: 2.136515069444007
# MAE: 1.089996982010968
# r2_score: 0.6780671873848234

# %% [markdown]
# # SVR poly

# %%
svr_p = SVR(kernel='poly')
svr_p.fit(x_train,y1_train)
print(svr_p.score(x_train,y1_train))
svrpred_p=svr_p.predict(x_test)
# Out:
# 0.8788949792033596

# %%
print('MSE:',mean_squared_error(svr_predict,y1_test))
print('MAE:',mean_absolute_error(svr_predict,y1_test))
print('r2_score:',r2_score(svr_predict,y1_test))
# Out:
# MSE: 2.136515069444007
# MAE: 1.089996982010968
# r2_score: 0.6780671873848234

# %% [markdown]
# # SVR rbf

# %%
svr_r = SVR(kernel='rbf')
svr_r.fit(x_train,y1_train)
print(svr_r.score(x_train,y1_train))
svrpred_r=svr_r.predict(x_test)
# Out:
# 0.8625287472711388

# %%
print('MSE:',mean_squared_error(svr_predict,y1_test))
print('MAE:',mean_absolute_error(svr_predict,y1_test))
print('r2_score:',r2_score(svr_predict,y1_test))
# Out:
# MSE: 2.136515069444007
# MAE: 1.089996982010968
# r2_score: 0.6780671873848234

# %% [markdown]
# # RandomForest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y1_train)
print(rf.score(x_train,y1_train))
rf_pred=rf.predict(x_test)
# Out:
# 0.9851584363612521

# %%
print('MSE:',mean_squared_error(rf_pred,y1_test))
print('MAE:',mean_absolute_error(rf_pred,y1_test))
print('r2_score:',r2_score(rf_pred,y1_test))
# Out:
# MSE: 0.8688361951038565
# MAE: 0.6892618694362015
# r2_score: 0.8759111307712515

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train,y1_train)
print(dtr.score(x_train,y1_train))
dtr_pred=dtr.predict(x_test)
# Out:
# 1.0

# %%
print('MSE:',mean_squared_error(dtr_pred,y1_test))
print('MAE:',mean_absolute_error(dtr_pred,y1_test))
print('r2_score:',r2_score(dtr_pred,y1_test))
# Out:
# MSE: 2.0395178041543027
# MAE: 1.0184718100890207
# r2_score: 0.7597973388931589

# %% [markdown]
# # Gradient Booster Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()
gbr.fit(x_train,y1_train)
print(gbr.score(x_train,y1_train))
gbr_pred=gbr.predict(x_test)
# Out:
# 0.8739146135897067

# %%
print('MSE:',mean_squared_error(gbr_pred,y1_test))
print('MAE:',mean_absolute_error(gbr_pred,y1_test))
print('r2_score:',r2_score(gbr_pred,y1_test))
# Out:
# MSE: 1.2683737263386905
# MAE: 0.8658378280530372
# r2_score: 0.8105023149106865

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,1,10],
            'random_state':list(range(0,10)),
            'fit_intercept':[True,False],
            'selection':['cyclic', 'random']}
ls = Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y1_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'fit_intercept': True, 'random_state': 7, 'selection': 'random'}

# %% [markdown]
# These are the best parameters

# %%
ls = Lasso(alpha=0.0001,random_state=7,fit_intercept=True,selection ='random')
ls.fit(x_train,y1_train)
ls.score(x_train,y1_train)

pred_ls=ls.predict(x_test)
lss=r2_score(y1_test,pred_ls)
lss
# Out:
# 0.7560333729967657

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
cv_score=cross_val_score(ls,x,y1,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.6890570748560018

# %%
print(cross_val_score(dtr,x,y1,cv=5).mean())
# Out:
# 0.3706025548809377

# %%
print(cross_val_score(svr,x,y1,cv=5).mean())
# Out:
# 0.6979600632861634

# %%
print(cross_val_score(svr_r,x,y1,cv=5).mean())
# Out:
# 0.6576643734126661

# %%
print(cross_val_score(svr_p,x,y1,cv=5).mean())
# Out:
# 0.5931448200997822

# %%
print(cross_val_score(gbr,x,y1,cv=5).mean())
# Out:
# 0.6871243452653696

# %%
print(cross_val_score(rf,x,y1,cv=5).mean())
# Out:
# 0.6740721310055345

# %%
print(cross_val_score(lr,x,y1,cv=5).mean())
# Out:
# 0.6889106857453933

# %% [markdown]
# Got the cross validation for each model. For enensemble technique choosing Linear regressor

# %% [markdown]
# # Ensemble technique, Hyperparameter tunning

# %%
from sklearn.model_selection import GridSearchCV

parameters={'fit_intercept':[True,False],
            'copy_X':[True,False],
            'positive':[True,False],
            'normalize':[True,False]
           }

# %%
lr=LinearRegression()
clf=GridSearchCV(lr,parameters)
clf.fit(x_train,y1_train)

print(clf.best_params_)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': False, 'positive': False}

# %% [markdown]
# These are the best parmeters

# %%
lr=LinearRegression(copy_X =True, fit_intercept=True, normalize=False, positive=False)
lr.fit(x_train,y1_train)
lr.score(x_train,y1_train)

pred_decision=lr.predict(x_test)
lrs=r2_score(y1_test,pred_decision)
print("R2_score",lrs*100)

lrs_score=cross_val_score(lr,x,y1,cv=5)
lrc=lrs_score.mean()
print("Cross_val_score",lrc*100)
# Out:
# R2_score 75.60269841061599
# Cross_val_score 68.89106857453933

# %% [markdown]
# Got 76% for the best model

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(lr,"Final Model of Temperature Forecast Project for max tem.pkl")
# Out:
# ['Final Model of Temperature Forecast Project for max tem.pkl']

# %% [markdown]
# saved the model

# %% [markdown]
# # conclusion

# %%
loaded_model=joblib.load(open('Final Model of Temperature Forecast Project for max tem.pkl','rb'))
result=loaded_model.score(x_test,y1_test)
print(result)
# Out:
# 0.7560269841061599

# %% [markdown]
# Got 90% in prediction

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  29.277934  31.402503  30.960057  34.882488  33.328444  28.744792
# Original   29.277934  31.402503  30.960057  34.882488  33.328444  28.744792
#
#                 6          7          8          9     ...       1338  \
# Predicted  30.363925  32.993239  33.280535  29.585039  ...  32.335572
# Original   30.363925  32.993239  33.280535  29.585039  ...  32.335572
#
#                 1339       1340       1341       1342       1343       1344  \
# Predicted  30.825759  27.691395  33.845092  31.298492  34.158913  26.302016
# Original   30.825759  27.691395  33.845092  31.298492  34.158913  26.302016
#
#                 1345       1346       1347
# Predicted  31.876048  31.092652  35.603535
# Original   31.876048  31.092652  35.603535
#
# [2 rows x 1348 columns]

# %% [markdown]
# Got it as predicted and original values are  same

# %% [markdown]
# # Taking Next_Tmin as Target

# %%
x_train,x_test,y2_train,y2_test=train_test_split(x,y2,test_size=.2,random_state=12)

# %%
x_train.shape
# Out:
# (5391, 23)

# %%
x_test.shape
# Out:
# (1348, 23)

# %%
y2_train.shape
# Out:
# (5391,)

# %%
y2_test.shape
# Out:
# (1348,)

# %% [markdown]
# # Find the best random states use here

# %%
lr.fit(x_train,y2_train)
# Out:
# LinearRegression()

# %% [markdown]
# linear regression fitting into x-train and y2-train

# %%
lr.coef_
# Out:
# array([-0.02556169,  0.34609542,  1.26385955,  2.9468152 ,  1.88062872,
#         0.19887534,  2.04182115,  7.4200642 ,  0.77043086,  0.23528654,
#        -0.19205952,  0.64463232, -0.15167443, -0.07511626, -0.15639467,
#        -0.59369517, -0.02855375, -0.32417099, -0.2429986 ,  0.09351152,
#        -1.43942297,  0.64330279,  0.14170997])

# %% [markdown]
# Got the linear regression constant

# %%
pred_test=lr.predict(x_test)

# %%
print("predicted value is",pred_test)
print("actual value is",y2_test)
# Out:
# predicted value is [23.70035065 23.83864717 20.43977644 ... 23.43396563 21.9265528
#  24.15038718]
# actual value is 5006    23.0
# 6479    25.0
# 4434    19.5
# 2347    25.3
# 6723    27.3
#         ...
# 7038    26.5
# 7318    21.5
# 1813    22.4
# 1440    20.3
# 5541    22.8
# Name: Next_Tmin, Length: 1348, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
print("mean absoute value",mean_absolute_error(y2_test,pred_test))
print("mean squared error",mean_squared_error(y2_test,pred_test))
print ("Root mean squared error",np.sqrt(mean_squared_error(y2_test,pred_test)))
# Out:
# mean absoute value 0.7827639985624426
# mean squared error 0.9678510190233438
# Root mean squared error 0.9837941954612986

# %%
print(r2_score(y2_test,pred_test))
# Out:
# 0.8296329355987289

# %% [markdown]
# r2_score got it as 83%

# %% [markdown]
# # SVR
# linear

# %%
from sklearn.svm import SVR

svr = SVR(kernel='linear')
svr.fit(x_train,y2_train)
print(svr.score(x_train,y2_train))
svr_predict=svr.predict(x_test)
# Out:
# 0.8188344343673076

# %%
print('MSE:',mean_squared_error(svr_predict,y2_test))
print('MAE:',mean_absolute_error(svr_predict,y2_test))
print('r2_score:',r2_score(svr_predict,y2_test))
# Out:
# MSE: 0.9758298377046015
# MAE: 0.7798973754621014
# r2_score: 0.7878362986534304

# %% [markdown]
# # SVR
# poly

# %%
svr_p = SVR(kernel='poly')
svr_p.fit(x_train,y2_train)
print(svr_p.score(x_train,y2_train))
svrpred_p=svr_p.predict(x_test)
# Out:
# 0.916790257764816

# %%
print('MSE:',mean_squared_error(svr_predict,y2_test))
print('MAE:',mean_absolute_error(svr_predict,y2_test))
print('r2_score:',r2_score(svr_predict,y2_test))
# Out:
# MSE: 0.9758298377046015
# MAE: 0.7798973754621014
# r2_score: 0.7878362986534304

# %% [markdown]
# # SVR rbf

# %%
svr_r = SVR(kernel='rbf')
svr_r.fit(x_train,y2_train)
print(svr_r.score(x_train,y2_train))
svrpred_r=svr_r.predict(x_test)
# Out:
# 0.9122041647793886

# %%
print('MSE:',mean_squared_error(svr_predict,y2_test))
print('MAE:',mean_absolute_error(svr_predict,y2_test))
print('r2_score:',r2_score(svr_predict,y2_test))
# Out:
# MSE: 0.9758298377046015
# MAE: 0.7798973754621014
# r2_score: 0.7878362986534304

# %% [markdown]
# # RandomForest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor()
rf.fit(x_train,y2_train)
print(rf.score(x_train,y2_train))
rf_pred=rf.predict(x_test)
# Out:
# 0.9855760683729339

# %%
print('MSE:',mean_squared_error(rf_pred,y2_test))
print('MAE:',mean_absolute_error(rf_pred,y2_test))
print('r2_score:',r2_score(rf_pred,y2_test))
# Out:
# MSE: 0.5244712099406531
# MAE: 0.5608494065281903
# r2_score: 0.888512713527831

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

dtr = DecisionTreeRegressor()
dtr.fit(x_train,y2_train)
print(dtr.score(x_train,y2_train))
dtr_pred=dtr.predict(x_test)
# Out:
# 1.0

# %%
print('MSE:',mean_squared_error(dtr_pred,y2_test))
print('MAE:',mean_absolute_error(dtr_pred,y2_test))
print('r2_score:',r2_score(dtr_pred,y2_test))
# Out:
# MSE: 1.221958456973294
# MAE: 0.8195845697329377
# r2_score: 0.7712026569565166

# %% [markdown]
# # Gradient Booster Regressor

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbr = GradientBoostingRegressor()
gbr.fit(x_train,y2_train)
print(gbr.score(x_train,y2_train))
gbr_pred=gbr.predict(x_test)
# Out:
# 0.9041186998641272

# %%
print('MSE:',mean_squared_error(gbr_pred,y2_test))
print('MAE:',mean_absolute_error(gbr_pred,y2_test))
print('r2_score:',r2_score(gbr_pred,y2_test))
# Out:
# MSE: 0.6107396926971279
# MAE: 0.6285234254882056
# r2_score: 0.8700046816399705

# %% [markdown]
# # Regularization

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV
import numpy as np

# %%
from sklearn.linear_model import Lasso

parameters={'alpha':[.0001,.001,.01,1,10],
            'random_state':list(range(0,10)),
            'fit_intercept':[True,False],
            'selection':['cyclic', 'random']}
ls = Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y2_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'fit_intercept': True, 'random_state': 7, 'selection': 'random'}

# %% [markdown]
# These are the best parameters

# %%
ls = Lasso(alpha=0.0001,random_state=7,fit_intercept=True,selection ='random')
ls.fit(x_train,y2_train)
ls.score(x_train,y2_train)

pred_ls=ls.predict(x_test)
lss=r2_score(y2_test,pred_ls)
lss
# Out:
# 0.8296548097448653

# %% [markdown]
# # cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(lr,x,y1,cv=5).mean())
# Out:
# 0.6889106857453933

# %%
cv_score=cross_val_score(ls,x,y2,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.7727983640401417

# %%
print(cross_val_score(dtr,x,y2,cv=5).mean())
# Out:
# 0.5651766123383464

# %%
print(cross_val_score(svr,x,y2,cv=5).mean())
# Out:
# 0.7686358760970907

# %%
print(cross_val_score(svr_r,x,y2,cv=5).mean())
# Out:
# 0.7481295420467986

# %%
print(cross_val_score(svr_p,x,y2,cv=5).mean())
# Out:
# 0.6922817757589523

# %%
print(cross_val_score(gbr,x,y2,cv=5).mean())
# Out:
# 0.7887813925347429

# %%
print(cross_val_score(rf,x,y2,cv=5).mean())
# Out:
# 0.7747852374082324

# %% [markdown]
# Got the cross validation for each model. For enensemble technique choosing linearRegressor

# %% [markdown]
# # Hyper parameter tunning

# %%
from sklearn.model_selection import GridSearchCV

parameters={'fit_intercept':[True,False],
            'copy_X':[True,False],
            'positive':[True,False],
            'normalize':[True,False]
           }

# %%
lr=LinearRegression()
clf=GridSearchCV(lr,parameters)
clf.fit(x_train,y2_train)

print(clf.best_params_)
# Out:
# {'copy_X': True, 'fit_intercept': True, 'normalize': True, 'positive': False}

# %% [markdown]
# These are the best parmeters

# %%
lr=LinearRegression(copy_X =True, fit_intercept=True, normalize=True, positive=False)
lr.fit(x_train,y2_train)
lr.score(x_train,y2_train)

pred_decision=lr.predict(x_test)
lrs=r2_score(y2_test,pred_decision)
print("R2_score",lrs*100)

lrs_score=cross_val_score(lr,x,y2,cv=5)
lrc=lrs_score.mean()
print("Cross_val_score",lrc*100)
# Out:
# R2_score 82.96329355987288
# Cross_val_score 77.26262258027975

# %% [markdown]
# Got 83% for the best model

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(lr,"Final Model of Temperature Forecast Project for min temp.pkl")
# Out:
# ['Final Model of Temperature Forecast Project for min temp.pkl']

# %% [markdown]
# saved the model

# %% [markdown]
# # conclusion

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_decision[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  29.277934  31.402503  30.960057  34.882488  33.328444  28.744792
# Original   23.700351  23.838647  20.439776  26.286141  27.067041  22.540580
#
#                 6          7          8          9     ...       1338  \
# Predicted  30.363925  32.993239  33.280535  29.585039  ...  32.335572
# Original   24.575979  26.637644  26.770568  21.134307  ...  23.386546
#
#                 1339       1340       1341       1342       1343       1344  \
# Predicted  30.825759  27.691395  33.845092  31.298492  34.158913  26.302016
# Original   20.980966  20.397405  26.056638  22.542642  26.471671  22.057963
#
#                 1345       1346       1347
# Predicted  31.876048  31.092652  35.603535
# Original   23.433966  21.926553  24.150387
#
# [2 rows x 1348 columns]

# %% [markdown]
# Got Predicted and actual value almost same
